# %% [markdown]
# # Esercizio 11.2

# %%
import os
os.environ['KMP_DUPLICATE_LIB_OK']='True'

# %%
# target parameters of f(x) = 3x^3 -2x^2 - 3x + 4
def f_x(x):
    a = 3
    b = -2
    c = -3
    d = 4
    return a*x**3 - b*x**2 - c*x + d

# %%
import numpy as np

N_train = 5000
N_valid = 500
# generate training inputs
np.random.seed(0)
x_train = np.random.uniform(-1, 1, N_train)
x_valid = np.random.uniform(-1, 1, N_valid)
x_valid.sort()
y_target = f_x(x_valid) # ideal (target) function

sigma = 1.0 # noise standard deviation
y_train = np.random.normal(f_x(x_train), sigma) # actual measures from which we want to guess regression parameters
y_valid = np.random.normal(f_x(x_valid), sigma)

# %%
# plot validation and target dataset
import matplotlib.pyplot as plt
plt.plot(x_valid, y_target, label='target')
plt.scatter(x_valid, y_valid, color='r', label='validation data')
plt.legend()
plt.grid(True)
plt.show()

# %%
# compose the NN model
import tensorflow as tf
from tensorflow import keras

from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Activation
from tensorflow.keras import backend as K
from tensorflow.keras.utils import get_custom_objects

model = tf.keras.Sequential()
model.add(Dense(10, input_shape=(1,)))
model.add(Dense(10))
model.add(Dense(10))
model.add(Dense(1))

# compile the model choosing optimizer, loss and metrics objects
model.compile(optimizer='sgd', loss='mse', metrics=['mse'])

# %%
# get a summary of our composed model
model.summary()
# Out:
# Model: "sequential_6"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_15 (Dense)            (None, 10)                20
#
#  dense_16 (Dense)            (None, 10)                110
#
#  dense_17 (Dense)            (None, 10)                110
#
#  dense_18 (Dense)            (None, 1)                 11
#
# =================================================================
# Total params: 251
# Trainable params: 251
# Non-trainable params: 0
# _________________________________________________________________

# %%
# fit the model using training dataset
# over 10 epochs of 32 batch size each
# report training progress against validation data
history = model.fit(x=x_train, y=y_train, 
          batch_size=50, epochs=100,
          shuffle=True, # a good idea is to shuffle input before at each epoch
          validation_data=(x_valid, y_valid))
# Out:
# Epoch 1/100
# 100/100 [==============================] - 0s 2ms/step - loss: 2.5938 - mse: 2.5938 - val_loss: 1.4893 - val_mse: 1.4893
# Epoch 2/100
# 100/100 [==============================] - 0s 1ms/step - loss: 1.5306 - mse: 1.5306 - val_loss: 1.5603 - val_mse: 1.5603
# Epoch 3/100
# 100/100 [==============================] - 0s 1ms/step - loss: 1.5284 - mse: 1.5284 - val_loss: 1.5004 - val_mse: 1.5004
# Epoch 4/100
# 100/100 [==============================] - 0s 1ms/step - loss: 1.5411 - mse: 1.5411 - val_loss: 1.4860 - val_mse: 1.4860
# Epoch 5/100
# 100/100 [==============================] - 0s 1ms/step - loss: 1.5420 - mse: 1.5420 - val_loss: 1.5189 - val_mse: 1.5189
# Epoch 6/100
# 100/100 [==============================] - 0s 1ms/step - loss: 1.5394 - mse: 1.5394 - val_loss: 1.5094 - val_mse: 1.5094
# Epoch 7/100
# 100/100 [==============================] - 0s 1ms/step - loss: 1.5274 - mse: 1.5274 - val_loss: 1.4904 - val_mse: 1.4904
# Epoch 8/100
# 100/100 [==============================] - 0s 1ms/step - loss: 1.5350 - mse: 1.5350 - val_loss: 1.4939 - val_mse: 1.4939
# Epoch 9/100
# 100/100 [==============================] - 0s 1ms/step - loss: 1.5425 - mse: 1.5425 - val_loss: 1.5154 - val_mse: 1.5154
# Epoch 10/100
# 100/100 [==============================] - 0s 1ms/step - loss: 1.5332 - mse: 1.5332 - val_loss: 1.5290 - val_mse: 1.5290
# Epoch 11/100
# 100/100 [==============================] - 0s 1ms/step - loss: 1.5315 - mse: 1.5315 - val_loss: 1.5707 - val_mse: 1.5707
# Epoch 12/100
# 100/100 [==============================] - 0s 1ms/step - loss: 1.5222 - mse: 1.5222 - val_loss: 1.5452 - val_mse: 1.5452
# Epoch 13/100
# 100/100 [==============================] - 0s 1ms/step - loss: 1.5353 - mse: 1.5353 - val_loss: 1.4895 - val_mse: 1.4895
# Epoch 14/100
# 100/100 [==============================] - 0s 1ms/step - loss: 1.5293 - mse: 1.5293 - val_loss: 1.5013 - val_mse: 1.5013
# Epoch 15/100
# 100/100 [==============================] - 0s 1ms/step - loss: 1.5416 - mse: 1.5416 - val_loss: 1.4920 - val_mse: 1.4920
# Epoch 16/100
# 100/100 [==============================] - 0s 1ms/step - loss: 1.5309 - mse: 1.5309 - val_loss: 1.4979 - val_mse: 1.4979
# Epoch 17/100
# 100/100 [==============================] - 0s 2ms/step - loss: 1.5356 - mse: 1.5356 - val_loss: 1.5561 - val_mse: 1.5561
# Epoch 18/100
# 100/100 [==============================] - 0s 1ms/step - loss: 1.5295 - mse: 1.5295 - val_loss: 1.5731 - val_mse: 1.5731
# Epoch 19/100
# 100/100 [==============================] - 0s 1ms/step - loss: 1.5299 - mse: 1.5299 - val_loss: 1.4897 - val_mse: 1.4897
# Epoch 20/100
# 100/100 [==============================] - 0s 1ms/step - loss: 1.5428 - mse: 1.5428 - val_loss: 1.4926 - val_mse: 1.4926
# Epoch 21/100
# 100/100 [==============================] - 0s 1ms/step - loss: 1.5212 - mse: 1.5212 - val_loss: 1.5508 - val_mse: 1.5508
# Epoch 22/100
# 100/100 [==============================] - 0s 2ms/step - loss: 1.5325 - mse: 1.5325 - val_loss: 1.5738 - val_mse: 1.5738
# Epoch 23/100
# 100/100 [==============================] - 0s 1ms/step - loss: 1.5450 - mse: 1.5450 - val_loss: 1.4908 - val_mse: 1.4908
# Epoch 24/100
# 100/100 [==============================] - 0s 1ms/step - loss: 1.5296 - mse: 1.5296 - val_loss: 1.4975 - val_mse: 1.4975
# Epoch 25/100
# 100/100 [==============================] - 0s 1ms/step - loss: 1.5202 - mse: 1.5202 - val_loss: 1.5054 - val_mse: 1.5054
# Epoch 26/100
# 100/100 [==============================] - 0s 2ms/step - loss: 1.5242 - mse: 1.5242 - val_loss: 1.5803 - val_mse: 1.5803
# Epoch 27/100
# 100/100 [==============================] - 0s 2ms/step - loss: 1.5274 - mse: 1.5274 - val_loss: 1.4845 - val_mse: 1.4845
# Epoch 28/100
# 100/100 [==============================] - 0s 2ms/step - loss: 1.5259 - mse: 1.5259 - val_loss: 1.5168 - val_mse: 1.5168
# Epoch 29/100
# 100/100 [==============================] - 0s 2ms/step - loss: 1.5342 - mse: 1.5342 - val_loss: 1.4963 - val_mse: 1.4963
# Epoch 30/100
# 100/100 [==============================] - 0s 2ms/step - loss: 1.
100
# 100/100 [==============================] - 0s 1ms/step - loss: 1.5348 - mse: 1.5348 - val_loss: 1.5002 - val_mse: 1.5002
# Epoch 69/100
# 100/100 [==============================] - 0s 1ms/step - loss: 1.5189 - mse: 1.5189 - val_loss: 1.4993 - val_mse: 1.4993
# Epoch 70/100
# 100/100 [==============================] - 0s 1ms/step - loss: 1.5250 - mse: 1.5250 - val_loss: 1.5205 - val_mse: 1.5205
# Epoch 71/100
# 100/100 [==============================] - 0s 1ms/step - loss: 1.5231 - mse: 1.5231 - val_loss: 1.5127 - val_mse: 1.5127
# Epoch 72/100
# 100/100 [==============================] - 0s 1ms/step - loss: 1.5247 - mse: 1.5247 - val_loss: 1.5213 - val_mse: 1.5213
# Epoch 73/100
# 100/100 [==============================] - 0s 1ms/step - loss: 1.5258 - mse: 1.5258 - val_loss: 1.5050 - val_mse: 1.5050
# Epoch 74/100
# 100/100 [==============================] - 0s 1ms/step - loss: 1.5198 - mse: 1.5198 - val_loss: 1.4983 - val_mse: 1.4983
# Epoch 75/100
# 100/100 [==============================] - 0s 1ms/step - loss: 1.5337 - mse: 1.5337 - val_loss: 1.4955 - val_mse: 1.4955
# Epoch 76/100
# 100/100 [==============================] - 0s 1ms/step - loss: 1.5270 - mse: 1.5270 - val_loss: 1.6133 - val_mse: 1.6133
# Epoch 77/100
# 100/100 [==============================] - 0s 1ms/step - loss: 1.5250 - mse: 1.5250 - val_loss: 1.5116 - val_mse: 1.5116
# Epoch 78/100
# 100/100 [==============================] - 0s 1ms/step - loss: 1.5265 - mse: 1.5265 - val_loss: 1.4988 - val_mse: 1.4988
# Epoch 79/100
# 100/100 [==============================] - 0s 1ms/step - loss: 1.5264 - mse: 1.5264 - val_loss: 1.5041 - val_mse: 1.5041
# Epoch 80/100
# 100/100 [==============================] - 0s 1ms/step - loss: 1.5280 - mse: 1.5280 - val_loss: 1.5271 - val_mse: 1.5271
# Epoch 81/100
# 100/100 [==============================] - 0s 1ms/step - loss: 1.5205 - mse: 1.5205 - val_loss: 1.5478 - val_mse: 1.5478
# Epoch 82/100
# 100/100 [==============================] - 0s 2ms/step - loss: 1.5288 - mse: 1.5288 - val_loss: 1.4979 - val_mse: 1.4979
# Epoch 83/100
# 100/100 [==============================] - 0s 1ms/step - loss: 1.5330 - mse: 1.5330 - val_loss: 1.5166 - val_mse: 1.5166
# Epoch 84/100
# 100/100 [==============================] - 0s 2ms/step - loss: 1.5226 - mse: 1.5226 - val_loss: 1.4999 - val_mse: 1.4999
# Epoch 85/100
# 100/100 [==============================] - 0s 1ms/step - loss: 1.5125 - mse: 1.5125 - val_loss: 1.5170 - val_mse: 1.5170
# Epoch 86/100
# 100/100 [==============================] - 0s 2ms/step - loss: 1.5284 - mse: 1.5284 - val_loss: 1.4965 - val_mse: 1.4965
# Epoch 87/100
# 100/100 [==============================] - 0s 1ms/step - loss: 1.5208 - mse: 1.5208 - val_loss: 1.5369 - val_mse: 1.5369
# Epoch 88/100
# 100/100 [==============================] - 0s 2ms/step - loss: 1.5281 - mse: 1.5281 - val_loss: 1.4980 - val_mse: 1.4980
# Epoch 89/100
# 100/100 [==============================] - 0s 2ms/step - loss: 1.5271 - mse: 1.5271 - val_loss: 1.4962 - val_mse: 1.4962
# Epoch 90/100
# 100/100 [==============================] - 0s 2ms/step - loss: 1.5212 - mse: 1.5212 - val_loss: 1.4993 - val_mse: 1.4993
# Epoch 91/100
# 100/100 [==============================] - 0s 2ms/step - loss: 1.5211 - mse: 1.5211 - val_loss: 1.5013 - val_mse: 1.5013
# Epoch 92/100
# 100/100 [==============================] - 0s 2ms/step - loss: 1.5262 - mse: 1.5262 - val_loss: 1.4953 - val_mse: 1.4953
# Epoch 93/100
# 100/100 [==============================] - 0s 2ms/step - loss: 1.5255 - mse: 1.5255 - val_loss: 1.5035 - val_mse: 1.5035
# Epoch 94/100
# 100/100 [==============================] - 0s 2ms/step - loss: 1.5296 - mse: 1.5296 - val_loss: 1.4948 - val_mse: 1.4948
# Epoch 95/100
# 100/100 [==============================] - 0s 2ms/step - loss: 1.5271 - mse: 1.5271 - val_loss: 1.4898 - val_mse: 1.4898
# Epoch 96/100
# 100/100 [==============================] - 0s 2ms/step - loss: 1.5324 - mse: 1.5324 - val_loss: 1.4973 - val_mse: 1.4973
# Epoch 97/100
# 100/100 [==============================] - 0s 2ms/step - loss: 1.5215 - mse: 1.5215 - val_loss: 1.4871 - val_mse: 1.4871
# Epoch 98/100
# 100/100 [==============================] - 0s 2ms/step - loss: 1.5279 - mse: 1.5279 - val_loss: 1.5448 - val_mse: 1.5448
# Epoch 99/100
# 100/100 [==============================] - 0s 2ms/step - loss: 1.5230 - mse: 1.5230 - val_loss: 1.4992 - val_mse: 1.4992
# Epoch 100/100
# 100/100 [==============================] - 0s 1ms/step - loss: 1.5272 - mse: 1.5272 - val_loss: 1.4861 - val_mse: 1.4861

# %%
score = model.evaluate(x_valid, y_valid, batch_size=32, verbose=1)

# print performance
print()
print('Test loss:', score[0])
print('Test accuracy:', score[1])

# look into training history

# summarize history for loss
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.ylabel('model loss')
plt.xlabel('epoch')
plt.legend(['train', 'test/validation'], loc='best')
plt.show()
# Out:
# 16/16 [==============================] - 0s 1ms/step - loss: 1.4861 - mse: 1.4861
#
# Test loss: 1.486143946647644
# Test accuracy: 1.486143946647644
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[54], line 11
#       6 print('Test accuracy:', score[1])
#       8 # look into training history
#       9
#      10 # summarize history for accuracy
# ---> 11 plt.plot(history.history['accuracy'])  # o 'acc' se usata durante l'addestramento
#      12 plt.plot(history.history['val_accuracy'])  # o 'val_acc' se usata durante la validazione
#      13 plt.ylabel('model accuracy')
#
# KeyError: 'accuracy'

# %%
x_predicted = np.random.uniform(-1, 1, 100)
y_predicted = model.predict(x_predicted)
plt.scatter(x_predicted, y_predicted,color='r')
plt.plot(x_valid, y_target)
plt.grid(True)
plt.show()
# Out:
# 4/4 [==============================] - 0s 4ms/step
